# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()

model = ChatOpenAI(model="openai/gpt-oss-20b")

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': '## Blog Outline – “Rise of AI in India”\n\n| # | Section | Sub‑Headings | Key Points / Content Ideas |\n|---|---------|--------------|---------------------------|\n| 1 | **Hook / Lead‑in** | | • Start with a striking statistic or story (e.g., AI market projected to hit ₹3.4\u202ftrillion by 2026). <br>• Pose a provocative question: “Is India ready to lead the AI revolution?” |\n| 2 | **Introduction** | • What is AI? <br>• Why focus on India? | • Briefly explain AI concepts (machine learning, deep learning, NLP, computer vision). <br>• Highlight India’s massive talent pool, startup ecosystem, and digital transformation momentum. |\n| 3 | **Historical Context** | • Early AI research in India <br>• Key milestones | • 1960s – MIT’s early AI work in India <br>• 1990s – AI labs at IITs & NITs <br>• 2000s – Government initiatives like “AI for All” (2018). |\n| 4 | **Government Leadership & Policies** | • National AI Strategy 2020 <br>• AI policy frameworks | • Ministry of Electronics & IT’s “Artificial Intelligence” policy (2018). <br>• Digital India and its AI alignment. <br>• Funding schemes (e.g., 10% of national budget for AI research). |\n| 5 | **Funding Landscape** | • Public sector investments <br>• Private venture capital | • AI Fund of the Indian Bank (₹100\u202fcr). <br>• Venture funds: Sequoia, Accel, SAIC, etc., investing in AI startups. |\n| 6 | **Talent Pipeline** | • Educational institutions <br>• Skill development programs | • AI labs at IIT Bombay, IIT Madras, IISc Bangalore. <br>• MOOCs, NPTEL AI courses, AI Bootcamps. <br>• Collaboration with global universities. |\n| 7 | **Industry Adoption by Sector** | • Healthcare <br>• Agriculture <br>• Finance <br>• Manufacturing <br>• Education | • AI‑driven diagnostics (e.g., AI‑based cancer screening). <br>• Precision agriculture (crop‑yield prediction). <br>• FinTech – fraud detection, credit scoring. <br>• Industry 4.0 – predictive maintenance. <br>• EdTech – personalized learning. |\n| 8 | **Start‑up Ecosystem** | • Startup hubs (Bangalore, Hyderabad, Pune) <br>• Success stories | • Companies like Niramai, SigTuple, Haptik, Mad Street Den. <br>• Funding rounds, unicorn status, global partnerships. |\n| 9 | **Key Success Stories / Case Studies** | • Niramai’s AI‑based breast cancer screening <br>• SigTuple’s automated lab diagnostics <br>• Haptik’s conversational AI <br>• Other regional examples | • Provide metrics (accuracy, cost savings, adoption rate). <br>• Highlight collaboration with public sector (e.g., AI for rural health). |\n| 10 | **AI in Government Services** | • Digital Services (Aadhaar, e‑Governance) <br>• Smart cities <br>• Public health surveillance | • AI in predictive policing, traffic management, disease outbreak modeling. |\n| 11 | **Infrastructure & Ecosystem** | • Cloud computing & edge devices <br>• AI‑specific hardware (NVIDIA, Intel, local fabs) | • Cloud adoption (AWS, Azure, Google Cloud). <br>• India’s own data centers and AI chips. |\n| 12 | **Data Ecosystem** | • Data availability <br>• Data privacy & protection laws | • Data trusts, open data initiatives. <br>• GDPR‑style frameworks: Personal Data Protection Bill. |\n| 13 | **Regulatory & Ethical Landscape** | • AI policy & guidelines <br>• Ethics boards, bias mitigation | • Guidelines by NITI Aayog. <br>• National AI Research Institute’s ethics charter. |\n| 14 | **Challenges & Constraints** | • Skill gaps <br>• Infrastructure bottlenecks <br>• Funding gaps <br>• Data quality & bias | • Need for interdisciplinary education. <br>• Rural digital divide. |\n| 15 | **Future Outlook & Predictions** | • AI market size projections <br>• Emerging use‑cases (autonomous vehicles, AR/VR, quantum AI) <br>• India’s role in global AI supply chain | • Forecasted CAGR (7–9% through 2030). <br>• Potential to become a top 5 AI market. |\n| 16 | **Recommendations for Stakeholders** | • For policymakers <br>• For educators <br>• For industry | • Incentivize open‑s ...

# %%
print(final_state['outline'])
# Out:
# ## Blog Outline – “Rise of AI in India”
#
# | # | Section | Sub‑Headings | Key Points / Content Ideas |
# |---|---------|--------------|---------------------------|
# | 1 | **Hook / Lead‑in** | | • Start with a striking statistic or story (e.g., AI market projected to hit ₹3.4 trillion by 2026). <br>• Pose a provocative question: “Is India ready to lead the AI revolution?” |
# | 2 | **Introduction** | • What is AI? <br>• Why focus on India? | • Briefly explain AI concepts (machine learning, deep learning, NLP, computer vision). <br>• Highlight India’s massive talent pool, startup ecosystem, and digital transformation momentum. |
# | 3 | **Historical Context** | • Early AI research in India <br>• Key milestones | • 1960s – MIT’s early AI work in India <br>• 1990s – AI labs at IITs & NITs <br>• 2000s – Government initiatives like “AI for All” (2018). |
# | 4 | **Government Leadership & Policies** | • National AI Strategy 2020 <br>• AI policy frameworks | • Ministry of Electronics & IT’s “Artificial Intelligence” policy (2018). <br>• Digital India and its AI alignment. <br>• Funding schemes (e.g., 10% of national budget for AI research). |
# | 5 | **Funding Landscape** | • Public sector investments <br>• Private venture capital | • AI Fund of the Indian Bank (₹100 cr). <br>• Venture funds: Sequoia, Accel, SAIC, etc., investing in AI startups. |
# | 6 | **Talent Pipeline** | • Educational institutions <br>• Skill development programs | • AI labs at IIT Bombay, IIT Madras, IISc Bangalore. <br>• MOOCs, NPTEL AI courses, AI Bootcamps. <br>• Collaboration with global universities. |
# | 7 | **Industry Adoption by Sector** | • Healthcare <br>• Agriculture <br>• Finance <br>• Manufacturing <br>• Education | • AI‑driven diagnostics (e.g., AI‑based cancer screening). <br>• Precision agriculture (crop‑yield prediction). <br>• FinTech – fraud detection, credit scoring. <br>• Industry 4.0 – predictive maintenance. <br>• EdTech – personalized learning. |
# | 8 | **Start‑up Ecosystem** | • Startup hubs (Bangalore, Hyderabad, Pune) <br>• Success stories | • Companies like Niramai, SigTuple, Haptik, Mad Street Den. <br>• Funding rounds, unicorn status, global partnerships. |
# | 9 | **Key Success Stories / Case Studies** | • Niramai’s AI‑based breast cancer screening <br>• SigTuple’s automated lab diagnostics <br>• Haptik’s conversational AI <br>• Other regional examples | • Provide metrics (accuracy, cost savings, adoption rate). <br>• Highlight collaboration with public sector (e.g., AI for rural health). |
# | 10 | **AI in Government Services** | • Digital Services (Aadhaar, e‑Governance) <br>• Smart cities <br>• Public health surveillance | • AI in predictive policing, traffic management, disease outbreak modeling. |
# | 11 | **Infrastructure & Ecosystem** | • Cloud computing & edge devices <br>• AI‑specific hardware (NVIDIA, Intel, local fabs) | • Cloud adoption (AWS, Azure, Google Cloud). <br>• India’s own data centers and AI chips. |
# | 12 | **Data Ecosystem** | • Data availability <br>• Data privacy & protection laws | • Data trusts, open data initiatives. <br>• GDPR‑style frameworks: Personal Data Protection Bill. |
# | 13 | **Regulatory & Ethical Landscape** | • AI policy & guidelines <br>• Ethics boards, bias mitigation | • Guidelines by NITI Aayog. <br>• National AI Research Institute’s ethics charter. |
# | 14 | **Challenges & Constraints** | • Skill gaps <br>• Infrastructure bottlenecks <br>• Funding gaps <br>• Data quality & bias | • Need for interdisciplinary education. <br>• Rural digital divide. |
# | 15 | **Future Outlook & Predictions** | • AI market size projections <br>• Emerging use‑cases (autonomous vehicles, AR/VR, quantum AI) <br>• India’s role in global AI supply chain | • Forecasted CAGR (7–9% through 2030). <br>• Potential to become a top 5 AI market. |
# | 16 | **Recommendations for Stakeholders** | • For policymakers <br>• For educators <br>• For industry | • Incentivize open‑source AI research. <br>• Integrate AI into STEM curricula. <br>• Public‑private partnership models. |
# | 17 | **Conclusion** | • Recap the trajectory <br>• Call to action | • Emphasize collective responsibility: government, academia, industry, and society. <br>• Invite readers to share their thoughts or contribute to AI initiatives. |
# | 18 | **Resources & Further Reading** | • Government portals <br>• Academic journals <br>• Key AI conferences | • AI Policy Documents, AI for All report. <br>• MIT AI India blog, NITI Aayog releases. |
# | 19 | **Interactive Elements** | • Embedded infographic <br>• AI timeline slider <br>• Call‑to‑action poll | • Show India’s AI growth graph. <br>• Survey: “Which AI industry excites you?” |
# | 20 | **SEO & Metadata** | • Target keywords <br>• Meta description <br>• Alt text for images | • Keywords: “AI in India”, “Indian AI startups”, “government AI policy India”, “AI adoption in agriculture India”. <br>• Meta: “Explore how artificial intelligence is transforming India’s economy, education, health, and more.” |
#
# ---
#
# ### Suggested Article Flow
#
# 1. **Intro & Hook** – Grab attention with a surprising fact or anecdote.
# 2. **Define & Contextualize AI** – A quick primer for non‑tech readers.
# 3. **Historical & Policy Foundations** – Show that India’s AI journey began long before the hype.
# 4. **Current State** – Highlight talent, funding, and sector adoption.
# 5. **Real‑World Success Stories** – Make the impact tangible.
# 6. **Challenges & Ethical Considerations** – Offer a balanced view.
# 7. **Looking Ahead** – End with optimistic but realistic predictions and actionable steps.
#
# Feel free to adapt the structure to fit your brand voice or target audience (e.g., entrepreneurs, policy advocates, technophiles). Happy writing!

# %%
print(final_state['content'])
# Out:
# # Rise of AI in India
# *From pioneering research labs to a booming startup ecosystem, India is fast becoming a global AI powerhouse.*
#
# ---
#
# ## 1. Hook / Lead‑in
# > “By 2026, India’s AI market is projected to hit **₹3.4 trillion**—a figure that dwarfs the current GDP contribution of the tech sector.”
# > **Question for the reader:** *Is India ready to lead the AI revolution?*
#
# ---
#
# ## 2. Introduction
#
# ### What is AI?
# Artificial Intelligence (AI) is the science of building machines that can perceive, learn, reason, and act like humans. At its core are:
#
# | Sub‑field | Brief Description |
# |---|---|
# | **Machine Learning** | Algorithms that improve from data. |
# | **Deep Learning** | Neural nets with many layers that excel in pattern recognition. |
# | **Natural Language Processing (NLP)** | Enabling machines to understand human language. |
# | **Computer Vision** | Teaching computers to interpret visual data. |
#
# ### Why focus on India?
# India offers a rare combination of:
#
# - **Massive talent pool** – over 10 million software engineers, 40 % of the world’s AI researchers in the last decade.
# - **Startup ecosystem** – 2,600+ AI startups with 200+ unicorns.
# - **Digital transformation momentum** – Digital India, 1.3 billion smartphone users, 1.2 billion internet users.
#
# ---
#
# ## 3. Historical Context
#
# | Period | Key Milestone |
# |---|---|
# | **1960s** | MIT researchers collaborated with Indian academia, laying groundwork for AI. |
# | **1990s** | AI labs formed at IITs & NITs, focusing on robotics & knowledge representation. |
# | **2000s** | “AI for All” concept first coined, setting a long‑term vision. |
# | **2018** | National “Artificial Intelligence” policy introduced, marking a shift from research to deployment. |
#
# ---
#
# ## 4. Government Leadership & Policies
#
# ### National AI Strategy (2020)
# - **Objective:** Position India among top 5 AI markets by 2030.
# - **Focus Areas:** Healthcare, agriculture, smart cities, manufacturing, and education.
#
# ### Policy Frameworks
# - **Ministry of Electronics & IT’s “Artificial Intelligence” policy (2018).**
# - **Digital India alignment** – AI as an enabler of e‑Governance, e‑Health, e‑Education.
# - **Funding:** 10 % of the national budget earmarked for AI research and development.
#
# ---
#
# ## 5. Funding Landscape
#
# | Investor | Investment Highlights |
# |---|---|
# | **Public sector** | AI Fund of Indian Bank – ₹100 cr for research & startups. |
# | **Venture capital** | Sequoia, Accel, SAIC, and local funds like Accel India & Blume Ventures. |
# | **Corporate** | Microsoft, Amazon, Google, and Tata Group’s AI labs. |
#
# ---
#
# ## 6. Talent Pipeline
#
# ### Educational Institutions
# - **IIT Bombay, IIT Madras, IISc Bangalore** – world‑class AI labs, PhD programs, and industry collaborations.
# - **NPTEL** – MOOCs on AI, ML, and data science for 1.5 M learners.
#
# ### Skill Development Programs
# - **AI Bootcamps** (e.g., by Infosys, TCS) – 12‑week intensive courses.
# - **Industry–academia partnerships** – internships, joint research grants.
#
# ---
#
# ## 7. Industry Adoption by Sector
#
# | Sector | Use‑case | Example |
# |---|---|---|
# | **Healthcare** | AI‑based diagnostics | **Niramai** – AI‑driven breast cancer screening. |
# | **Agriculture** | Precision farming | Crop‑yield prediction using satellite imagery. |
# | **Finance** | Fraud detection | FinTech platforms using ML for real‑time risk scoring. |
# | **Manufacturing** | Predictive maintenance | AI in predictive analytics for equipment health. |
# | **Education** | Personalized learning | EdTech platforms using adaptive learning algorithms. |
#
# ---
#
# ## 8. Start‑up Ecosystem
#
# ### Hubs
# - **Bangalore** – “Silicon Valley of India.”
# - **Hyderabad** – Tech corridor, thriving AI community.
# - **Pune** – Growing talent pool & startup support.
#
# ### Success Stories
# - **Niramai** – ₹80 cr Series‑C, unicorn status.
# - **SigTuple** – $30 M Series‑A for automated lab diagnostics.
# - **Haptik** – $70 M Series‑C, leading conversational AI.
# - **Mad Street Den** – AI for retail, acquired by Tata.
#
# ---
#
# ## 9. Key Success Stories / Case Studies
#
# | Company | Domain | Impact |
# |---|---|---|
# | **Niramai** | Breast cancer screening | 96% accuracy, 50% lower cost than conventional mammograms. |
# | **SigTuple** | Lab diagnostics | 5× faster turnaround, 90% reduction in human error. |
# | **Haptik** | Conversational AI | 10M+ users, 200+ enterprise partners. |
# | **Affectiva** | Emotion analytics | Used by government for public sentiment analysis. |
#
# ---
#
# ## 10. AI in Government Services
#
# - **Digital Services:** AI in Aadhaar authentication, e‑Governance chatbots.
# - **Smart Cities:** Predictive policing, traffic flow optimization.
# - **Public Health Surveillance:** AI models for COVID‑19 spread, dengue outbreak prediction.
#
# ---
#
# ## 11. Infrastructure & Ecosystem
#
# - **Cloud & Edge:** AWS India, Azure India, Google Cloud – 50+ data centers.
# - **Hardware:** NVIDIA, Intel, local fabs (e.g., Tata Consultancy).
# - **AI‑specific hardware:** Emerging domestic AI chip startups (e.g., Infinix, PrimeSense).
#
# ---
#
# ## 12. Data Ecosystem
#
# - **Data availability:** 2 PB+ of public data from e‑Governance portals.
# - **Data trusts & open data initiatives** – e.g., India Data Trust (IDT).
# - **Privacy & protection** – Personal Data Protection Bill (2023) provides GDPR‑style framework.
#
# ---
#
# ## 13. Regulatory & Ethical Landscape
#
# | Body | Initiative |
# |---|---|
# | **NITI Aayog** | AI guidelines, ethical frameworks. |
# | **National AI Research Institute** | Ethics charter, bias mitigation guidelines. |
# | **AI Ethics Boards** | Multi‑stakeholder boards in major companies. |
#
# ---
#
# ## 14. Challenges & Constraints
#
# - **Skill gaps** – Need for interdisciplinary education (AI + domain expertise).
# - **Infrastructure bottlenecks** – Rural connectivity, limited AI‑ready hardware.
# - **Funding gaps** – Despite growth, VC funding remains lower than China & US.
# - **Data quality & bias** – Lack of standardized datasets, risk of algorithmic bias.
#
# ---
#
# ## 15. Future Outlook & Predictions
#
# - **Market size:** CAGR 7–9% to 2029; projected to reach **₹6.5 trillion** by 2030.
# - **Emerging use‑cases:** Autonomous vehicles, AR/VR, quantum‑AI hybrids.
# - **Supply chain role:** India to become a leading AI chip manufacturer, part of global AI supply chain.
#
# ---
#
# ## 16. Recommendations for Stakeholders
#
# ### For policymakers
# - Incentivize open‑source AI research.
# - Increase public funding for AI‑related PhDs.
#
# ### For educators
# - Integrate AI modules into STEM curricula from high school onwards.
# - Encourage industry‑led labs and internships.
#
# ### For industry
# - Adopt public‑private partnership models for large‑scale AI deployments.
# - Embrace ethical AI frameworks proactively.
#
# ---
#
# ## 17. Conclusion
#
# India’s AI journey is no longer a distant dream—it is unfolding daily. From research labs to rural health clinics, AI is reshaping sectors, creating jobs, and driving economic growth. **Collective responsibility**—government, academia, industry, and society—will determine how far this momentum can go.
#
# *What AI domain excites you most? Share your thoughts below or contribute to an AI initiative that matters to you.*
#
# ---
#
# ## 18. Resources & Further Reading
#
# | Resource | Link |
# |---|---|
# | **National AI Strategy 2020** | https://www.mei.gov.in |
# | **AI Policy Documents** | https://www.niti.gov.in/ai-policy |
# | **NITI Aayog AI Reports** | https://www.niti.gov.in/ai-reports |
# | **MIT AI India Blog** | https://ai.mit.edu/india |
# | **AI Conferences (e.g., Indian Conference on AI & Big Data)** |
