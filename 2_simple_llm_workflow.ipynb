# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI(model="openai/gpt-oss-20b")

# %%
# create a state

class LLMState(TypedDict):

    question: str
    answer: str

# %%
def llm_qa(state: LLMState) -> LLMState:

    # extract the question from state
    question = state['question']

    # form a prompt
    prompt = f'Answer the following question {question}'

    # ask that question to the LLM
    answer = model.invoke(prompt).content

    # update the answer in the state
    state['answer'] = answer

    return state

# %%
# create our graph

graph = StateGraph(LLMState)

# add nodes
graph.add_node('llm_qa', llm_qa)

# add edges
graph.add_edge(START, 'llm_qa')
graph.add_edge('llm_qa', END)

# compile
workflow = graph.compile()

# %%
# execute

intial_state = {'question': 'How far is moon from the earth?'}

final_state = workflow.invoke(intial_state)

print(final_state['answer'])
# Out:
# The average distance from Earth to the Moon is about **384,400 km** (≈238,855 miles).
# - **Perigee (closest point):** ~363,300 km
# - **Apogee (farthest point):** ~405,500 km
#
# So the distance varies between roughly 363,000 km and 406,000 km, with the mean value around 384,400 km.

# %%
model.invoke('How far is moon from the earth?').content
# Out:
# 'The Moon orbits Earth at an average distance of **about 384,400\u202fkilometres (≈238,855\u202fmiles)**.  \nBecause the Moon’s orbit is slightly elliptical, the distance varies:\n\n| Distance | Occurrence | Approx. value |\n|----------|------------|--------------|\n| **Perigee** (closest) | ~4\u202fJanuary (and every ~27.3\u202fdays) | 363,104\u202fkm (225,623\u202fmi) |\n| **Average** (mean) | — | 384,400\u202fkm (238,855\u202fmi) |\n| **Apogee** (farthest) | ~15\u202fJuly (and every ~27.3\u202fdays) | 405,696\u202fkm (252,088\u202fmi) |\n\nSo while the “average” distance is often quoted as 384,400\u202fkm, the Moon swings between roughly 363,000\u202fkm and 406,000\u202fkm as it travels its 27‑day orbit.'

# %%
model.invoke('complete system design of facebook?').content
# Out:
# '# System Design of a Facebook‑Like Social Network  \n*(High‑Level Architecture, Core Services, Scaling Strategies, Data Model, Technology Choices, and Operational Concerns)*  \n\n> **Audience:** System designers, architects, and senior engineers.  \n> **Scope:** A production‑grade, global, highly‑available social network that supports millions of concurrent users, billions of posts, and real‑time interactions.  \n\n---\n\n## 1. Core Requirements\n\n| Category | Requirement | Notes |\n|----------|-------------|-------|\n| **Functional** | • User registration, login, profile management | Social graph, friends/followers |\n| | • Content posting (text, images, videos) | Rich media, moderation |\n| | • News feed / timeline (personalized ranking) | Real‑time, large volume |\n| | • Likes, comments, shares | Interaction graph |\n| | • Real‑time notifications | Push & in‑app |\n| | • Messaging (one‑to‑one & group chat) | End‑to‑end encryption |\n| | • Search (users, posts, hashtags, places) | Full‑text, faceted |\n| | • Advertising & recommendation | Targeted ads, bidding |\n| **Non‑Functional** | • 100\u202fM+ daily active users (DAU) | Global distribution |\n| | • < 500\u202fms end‑to‑end latency | Mobile & web |\n| | • 99.99\u202f% availability | Multi‑region |\n| | • GDPR / CCPA compliant | Data residency, deletion |\n| | • Strong data privacy & security | Encryption, access control |\n| | • Continuous deployment | Zero‑downtime releases |\n\n---\n\n## 2. High‑Level Architecture\n\n```\n┌──────────────────────────────────────────────────────────────────────────────┐\n│                                CDN (CloudFront / Akamai)                   │\n│ ─────────────────────────────────────────────────────────────────────────── │\n│                     │                                               │\n│                     ▼                                               ▼\n│          ┌─────────────────┐                               ┌─────────────────┐\n│          │  Edge API Layer │                               │  Edge API Layer │\n│          │  (Load Balancer,│                               │  (Regional LB)  │\n│          │   WAF, Rate‑Limiting)                            │  (Auth, Routing)│\n│          └─────────────────┘                               └─────────────────┘\n│                     │                                               │\n│                     ▼                                               ▼\n│         ┌───────────────────────┐                          ┌───────────────────────┐\n│         │   Microservice Mesh   │                          │   Microservice Mesh   │\n│         │ (gRPC / HTTP/2, Envoy)│                          │  (gRPC / HTTP/2, Envoy)│\n│         └───────────────────────┘                          └───────────────────────┘\n│          │          │          │              │          │          │          │\n│          ▼          ▼          ▼              ▼          ▼          ▼          ▼\n│  ┌───────┐   ┌───────┐   ┌───────┐      ┌───────┐   ┌───────┐   ┌───────┐   ┌───────┐\n│  │User   │   │Content│   │Feed   │      │Msg    │   │Notify │   │Search │   │Ads    │\n│  │Profile│   │Store  │   │Engine │      │Service│   │Service│   │Service│   │Service│\n│  └───────┘   └───────┘   └───────┘      └───────┘   └───────┘   └───────┘   └───────┘\n│      │          │          │              │          │          │          │\n│      ▼          ▼          ▼              ▼          ▼          ▼          ▼\n│  ┌─────────┐  ┌─────────┐  ┌─────────┐    ┌─────────┐  ┌─────────┐  ┌─────────┐  ┌─────────┐\n│  │MySQL    │  │Redis    │  │Elastic  │    │Kafka    │  │Redis    │  │Elastic  │  │Redis    │\n│  │Cluster │  │Cache    │  │Search   │    │Stream   │  │Cache    │  │Search   │  │Cache    │\n│  └─────────┘  └─────────┘  └─────────┘    └─────────┘  └─────────┘  └─────────┘  └─────────┘\n│      │          │          │              │          │          │          │\n│      ▼          ▼          ▼              ▼  ...
